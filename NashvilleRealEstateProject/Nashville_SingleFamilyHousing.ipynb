# %%
import pandas as pd
import numpy as np

filename = "Nashville_housing_data_2013_2016.csv"
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         Parcel ID           Land Use  \
# 0           0             0  105 03 0D 008.00  RESIDENTIAL CONDO
# 1           1             1   105 11 0 080.00      SINGLE FAMILY
# 2           2             2   118 03 0 130.00      SINGLE FAMILY
# 3           3             3   119 01 0 479.00      SINGLE FAMILY
# 4           4             4   119 05 0 186.00      SINGLE FAMILY
#
#     Property Address Suite/ Condo   # Property City   Sale Date  Sale Price  \
# 0    1208  3RD AVE S                8     NASHVILLE  2013-01-24      132000
# 1   1802  STEWART PL              NaN     NASHVILLE  2013-01-11      191500
# 2  2761  ROSEDALE PL              NaN     NASHVILLE  2013-01-18      202000
# 3  224  PEACHTREE ST              NaN     NASHVILLE  2013-01-18       32000
# 4      316  LUTIE ST              NaN     NASHVILLE  2013-01-23      102000
#
#     Legal Reference    ...    Building Value Total Value Finished Area  \
# ...

# %%
#remove useless or duplicate info columns
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Parcel ID','State', 'City', 'Legal Reference', 'image', 'Tax District', 'Sold As Vacant', 'Suite/ Condo   #', 'Property City', 'Multiple Parcels Involved in Sale', 'Owner Name', 'Address'], axis = 1)

# %%
df.count()
# Out:
# Land Use            56636
# Property Address    56477
# Sale Date           56636
# Sale Price          56636
# Acreage             26017
# Neighborhood        26017
# Land Value          26017
# Building Value      26017
# Total Value         26017
# Finished Area       24166
# Foundation Type     24164
# Year Built          24165
# Exterior Wall       24165
# Grade               24165
# Bedrooms            24159
# Full Bath           24277
# Half Bath           24146
# dtype: int64

# %%
#copied from Maria Victoria's notebook

residence =['RESIDENTIAL CONDO', 'SINGLE FAMILY', 'APARTMENT: LOW RISE (BUILT SINCE 1960)','DUPLEX',
       'CONDO', 'ZERO LOT LINE', 'RESIDENTIAL COMBO/MISC', 'TRIPLEX','QUADPLEX',
                'DORMITORY/BOARDING HOUSE', 'MOBILE HOME', 'PARSONAGE']
    
commerical = ['SMALL SERVICE SHOP', 'TERMINAL/DISTRIBUTION WAREHOUSE',
       'NON-PROFIT CHARITABLE SERVICE',
       'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK', 'NIGHTCLUB/LOUNGE',
       'MORTUARY/CEMETERY', 'PARKING LOT','OFFICE BLDG (ONE OR TWO STORIES)', 
        'CLUB/UNION HALL/LODGE', 'LIGHT MANUFACTURING',
       'ONE STORY GENERAL RETAIL STORE', 'DAY CARE CENTER','CHURCH']
    
vacant = ['VACANT RES LAND', 'VACANT COMMERCIAL LAND', 'VACANT RURAL LAND','VACANT ZONED MULTI FAMILY', 
              'VACANT RESIDENTIAL LAND','VACANT RESIENTIAL LAND']
    
other = ['GREENBELT','GREENBELT/RES\nGRRENBELT/RES']

# %%
#create dataframe with only rows that are residence
df_housing = df[(df['Land Use'].isin(residence))]

# %%
df_housing.head()
#df_housing.count()
# Out:
#             Land Use   Property Address   Sale Date  Sale Price  Acreage  \
# 0  RESIDENTIAL CONDO    1208  3RD AVE S  2013-01-24      132000      NaN
# 1      SINGLE FAMILY   1802  STEWART PL  2013-01-11      191500     0.17
# 2      SINGLE FAMILY  2761  ROSEDALE PL  2013-01-18      202000     0.11
# 3      SINGLE FAMILY  224  PEACHTREE ST  2013-01-18       32000     0.17
# 4      SINGLE FAMILY      316  LUTIE ST  2013-01-23      102000     0.34
#
#    Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 0           NaN         NaN             NaN          NaN            NaN
# 1        3127.0     32000.0        134400.0     168300.0     1149.00000
# 2        9126.0     34000.0        157800.0     191800.0     2090.82495
# 3        3130.0     25000.0        243700.0     268700.0     2145.60001
# 4        3130.0     25000.0        138100.0     164800.0     1969.00000
#
#   Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# ...

# %% [markdown]
# In this dataset, I'm only going to keep the housing types that are Single Family because it has the most Neighborhood information available. I will remove all rows that don't have an address and don't have a neighborhood assigned to it.
#
# Then, all the duplicate property addresses are removed except for the address with the most current sale date.
#
# The 'Neighborhood' column will be converted into a str, so it can be used as a category, and the 'Sale Price' column will be turned into a float for more precision when doing calculations using this column.

# %%
#make dataframe containing only Single Family houses
df_SingleFamily = df_housing[df_housing['Land Use'] == 'SINGLE FAMILY']

df_SingleFamily.count()
# Out:
# Land Use            34268
# Property Address    34197
# Sale Date           34268
# Sale Price          34268
# Acreage             21877
# Neighborhood        21877
# Land Value          21877
# Building Value      21877
# Total Value         21877
# Finished Area       21390
# Foundation Type     21389
# Year Built          21390
# Exterior Wall       21390
# Grade               21390
# Bedrooms            21387
# Full Bath           21389
# Half Bath           21289
# dtype: int64

# %%
df_SingleFamily.tail()
# Out:
#             Land Use       Property Address   Sale Date  Sale Price  Acreage  \
# 56605  SINGLE FAMILY      5004 SUNSHINE  DR  2016-10-26      214000     0.27
# 56606  SINGLE FAMILY    6724 BIRCHBROOK  DR  2016-10-31      178000      NaN
# 56607  SINGLE FAMILY  4964 HICKORY WOODS  E  2016-10-28      236000     0.23
# 56614  SINGLE FAMILY        1625 5TH  AVE N  2016-10-28      466000     0.15
# 56615  SINGLE FAMILY        1614 5TH  AVE N  2016-10-26      685000     0.19
#
#        Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 56605        6328.0     25000.0        142400.0     167400.0         2421.0
# 56606           NaN         NaN             NaN          NaN            NaN
# 56607        6328.0     25000.0        159300.0     184300.0         3117.0
# 56614         126.0     40000.0        204100.0     256000.0         1637.0
# 56615         126.0     40000.0        295900.0     351600.0         2478.0
#
# ...

# %%
#delete rows w/ no property address
#delete rows with no neighborhood

df_SingleFamily = df_SingleFamily.dropna(subset=['Property Address'])
df_SingleFamily = df_SingleFamily.dropna(subset=['Neighborhood'])
df_SingleFamily.count()
# Out:
# Land Use            21875
# Property Address    21875
# Sale Date           21875
# Sale Price          21875
# Acreage             21875
# Neighborhood        21875
# Land Value          21875
# Building Value      21875
# Total Value         21875
# Finished Area       21388
# Foundation Type     21387
# Year Built          21388
# Exterior Wall       21388
# Grade               21388
# Bedrooms            21385
# Full Bath           21387
# Half Bath           21287
# dtype: int64

# %%
#looking at duplicate properties with multiple sale dates
address = df_SingleFamily["Property Address"]
df_SingleFamily[address.isin(address[address.duplicated()])].sort_values("Property Address")
# Out:
#             Land Use       Property Address   Sale Date  Sale Price  Acreage  \
# 12712  SINGLE FAMILY       1000  11TH AVE N  2014-02-28      210000     0.10
# 9305   SINGLE FAMILY       1000  11TH AVE N  2013-10-18       85028     0.10
# 33362  SINGLE FAMILY    1000  LIVINGSTON ST  2015-06-16      119900     0.34
# 6026   SINGLE FAMILY    1000  LIVINGSTON ST  2013-07-30       61500     0.34
# 28590  SINGLE FAMILY     1000  OAK RIDGE CT  2015-03-17      110000     0.28
# 35434  SINGLE FAMILY     1000  OAK RIDGE CT  2015-07-30      133800     0.28
# 13499  SINGLE FAMILY      1000  SEYMOUR AVE  2014-03-04      135000     0.26
# 25226  SINGLE FAMILY      1000  SEYMOUR AVE  2014-12-08      335000     0.26
# 22872  SINGLE FAMILY    1001  MCCLURKAN AVE  2014-10-31      314900     0.17
# 14542  SINGLE FAMILY    1001  MCCLURKAN AVE  2014-04-07      105000     0.17
# 5872   SINGLE FAMILY      1001  MCMAHAN AVE  2013-07-31      264900     0.34
# ...

# %%
#change 'Sale Date' values to datetime format; assign to new column
df_SingleFamily['SaleDT'] = pd.to_datetime(df_SingleFamily['Sale Date'])

#keep most recent sale for a property address
df_SingleFamilyCurrent = df_SingleFamily.groupby('Property Address', group_keys=False, as_index=False).apply(lambda x: x.loc[np.argmax(x['SaleDT'])])

# %%
df_SingleFamilyCurrent.count()
# Out:
# Land Use            19719
# Property Address    19719
# Sale Date           19719
# Sale Price          19719
# Acreage             19719
# Neighborhood        19719
# Land Value          19719
# Building Value      19719
# Total Value         19719
# Finished Area       19289
# Foundation Type     19288
# Year Built          19289
# Exterior Wall       19289
# Grade               19289
# Bedrooms            19286
# Full Bath           19288
# Half Bath           19197
# SaleDT              19719
# dtype: int64

# %%
df_SingleFamilyCurrent.head()
# Out:
#         Land Use     Property Address   Sale Date  Sale Price  Acreage  \
# 0  SINGLE FAMILY      0 E NOCTURNE DR  2016-03-03      110250     0.25
# 1  SINGLE FAMILY  1  PEACH BLOSSOM SQ  2015-08-31      745000     0.16
# 2  SINGLE FAMILY        1  WATERS AVE  2013-08-12      365000     0.37
# 3  SINGLE FAMILY          1 FERN  AVE  2016-08-30      275000     0.07
# 4  SINGLE FAMILY        1 WATERS  AVE  2016-06-15      465000     0.37
#
#    Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 0        3527.0     11000.0         92300.0     103300.0         1384.0
# 1        3246.0    180000.0        338100.0     525200.0         2397.0
# 2        2726.0     43900.0        249000.0     299600.0         1986.0
# 3        3426.0      8400.0         36200.0      44600.0          680.0
# 4        2726.0     43900.0        249000.0     299600.0         1986.0
#
#   Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# ...

# %%
#convert neighborhood type from float->int->str to use as categorical variable
df_SingleFamilyCurrent['Neighborhood'] = df_SingleFamilyCurrent.loc[:, ['Neighborhood']].astype(int)
df_SingleFamilyCurrent['Neighborhood'] = df_SingleFamilyCurrent.loc[:, ['Neighborhood']].astype(str)
df_SingleFamilyCurrent['Neighborhood'].dtype
# Out:
# dtype('O')

# %%
df_SingleFamilyCurrent['Sale Price'].dtype
# Out:
# dtype('int64')

# %%
#convert 'Sale Price' from int->float
df_SingleFamilyCurrent['Sale Price'] = df_SingleFamilyCurrent.loc[:, ['Sale Price']].astype(float)
df_SingleFamilyCurrent['Sale Price'].dtype
# Out:
# dtype('float64')

# %%
df_SingleFamilyCurrent.to_csv("Nashville_SingleFamilyHousing.csv", index=False)
